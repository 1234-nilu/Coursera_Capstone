# %% [markdown]
# # This notebook contains code used for the Capstone Final Project

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-1                   --> 2019.9.11-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_1              --> 2019.9.11-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1c-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# ca-certificates-2019 | 144 KB    | ##################################### | 100%
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         868 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.2.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_2143db3fdacf44908425056707f909f7 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='xYSdCptWa9-tEzDufzfEjBeNqSB6_ayWulzxd5Et1c_Z',
    ibm_auth_endpoint="https://iam.au-syd.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.ap-geo.objectstorage.service.networklayer.com')

body = client_2143db3fdacf44908425056707f909f7.get_object(Bucket='hellocapstone-donotdelete-pr-4v0tdkq1bi8kbc',Key='top_bottom_ratio.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df = pd.read_csv(body)
df.head()
# Out:
#    Rank (from highest to lowest ratio)                  Metropolitan area  \
# 0                                    1                     Jackson, WY-ID
# 1                                    2    Bridgeport-Stamford-Norwalk, CT
# 2                                    3  Naples-Immokalee-Marco Island, FL
# 3                                    4           Sebastian-Vero Beach, FL
# 4                                    5                       Key West, FL
#
#    Average income of the top 1%  Average income of the bottom 99%  \
# 0                      19995834                             93891
# 1                       6061230                             82222
# 2                       4191055                             57258
# 3                       2519981                             39710
# 4                       3193353                             54615
#
#    Top-to-bottom ratio
# 0                213.0
# 1                 73.7
# 2                 73.2
# 3                 63.5
# 4                 58.5

# %%
df= df.sort_values('Average income of the top 1%', ascending=False)

# %%
#top 30 
df_cut=df.head(30)
del df_cut['Rank (from highest to lowest ratio)']
df_cut
# Out:
#                              Metropolitan area  Average income of the top 1%  \
# 0                               Jackson, WY-ID                      19995834
# 1              Bridgeport-Stamford-Norwalk, CT                       6061230
# 2            Naples-Immokalee-Marco Island, FL                       4191055
# 11                             Summit Park, UT                       4008668
# 37                               Williston, ND                       3402874
# 7                                  Midland, TX                       3364922
# 4                                 Key West, FL                       3193353
# 21          San Jose-Sunnyvale-Santa Clara, CA                       2732379
# 3                     Sebastian-Vero Beach, FL                       2519981
# 8                         Glenwood Springs, CO                       2441991
# 14                                  Hailey, ID                       2226561
# 24           San Francisco-Oakland-Hayward, CA                       2168628
# 12       New York-Newark-Jersey City, NY-NJ-PA                       2156193
# 29                                 Edwards, CO                       2055108
# 5                     Gardnerville Ranchos, NV                       2054149
# 22              Boston-Cambridge-Newton, MA-NH                       1963545
# 118                              Dickinson, ND                       1899898
# 6    Miami-Fort Lauderdale-West Palm Beach, FL                       1789754
# 28                       Steamboat Springs, CO                       1772705
# 60                                 Boulder, CO                       1714866
# 25                                  Casper, WY                       1710626
# 34        Houston-The Woodlands-Sugar Land, TX                       1691321
# 9                               San Angelo, TX                       1645923
# 38                                 Trenton, NJ                       1632830
# 19       Fayetteville-Springdale-Rogers, AR-MO                       1594106
# 16                                Victoria, TX                       1564953
# 36                                  Easton, MD                       1504912
# 10            Las Vegas-Henderson-Paradise, NV                       1459955
# 45                                    Napa, CA                       1458589
# 27          Los Angeles-Long Beach-Anaheim, CA                       1455805
#
#      Average income of the bottom 99%  Top-to-bottom ratio
# 0                               93891                213.0
# 1                               82222                 73.7
# 2                               57258                 73.2
# 11                              99468                 40.3
# 37                             122496                 27.8
# 7                               75980                 44.3
# 4                               54615                 58.5
# 21                              85042                 32.1
# 3                               39710                 63.5
# 8                               57634                 42.4
# 14                              61404                 36.3
# 24                              70994                 30.5
# 12                              54895                 39.3
# 29                              69343                 29.6
# 5                               44529                 46.1
# 22                              64135                 30.6
# 118                             90640                 21.0
# 6                               39778                 45.0
# 28                              59505                 29.8
# 60                              68980                 24.9
# 25                              56326                 30.4
# 34                              59161                 28.6
# 9                               40287                 40.9
# 38                              60245                 27.1
# 19                              48151                 33.1
# 16                              46636                 33.6
# 36                              54139                 27.8
# 10                              35895                 40.7
# 45                              55808                 26.1
# 27                              48492                 30.0

# %% [markdown]
# we need to ensure that this 1% population is a significant chunk in absolute terms as well. For example 1% of city A with population 1000 is 10 whereas 1% of city B with population 100000 is 1000. Clearly the 1% of city B is more meaningful to be pursued rather than the 1% of city A.
# Therefore lets get the population data of top 20 most populous metropolitan areas in the US

# %%
#body = client_2143db3fdacf44908425056707f909f7.get_object(Bucket='hellocapstone-donotdelete-pr-4v0tdkq1bi8kbc',Key='Book2.csv')['Body']
#if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

#df_data_0 = pd.read_excel(body)
#df_data_0.head()

# %% [markdown]
# The list of the most populous metropolitan areas in US is easily available. Below, we have a list we got from https://www.currentresults.com/Weather-Extremes/US/largest-cities-list.php . The metropolitan area with the highest population is on the top. We have selected the cities with population >= 3million and directly pasted them into a list.

# %%
topm = [('New York-Newark-Jersey City, NY-NJ-PA',18897109),('Los Angeles-Long Beach-Anaheim, CA',12828837),('Chicago-Joliet-Naperville, IL-IN-WI',9461105),('Dallas-Fort Worth-Arlington, TX',6371773),('Philadelphia-Camden-Wilmington, PA-NJ-DE-MD',5965343),('Houston-The Woodlands-Sugar Land, TX',5946800),('Washington-Arlington-Alexandria, DC-VA-MD-WV',5582170),('Miami-Fort Lauderdale-West Palm Beach, FL',5564635),('Atlanta-Sandy Springs-Marietta, GA',5268860),('Boston-Cambridge-Newton, MA-NH',4552402),('San Francisco-Oakland-Hayward, CA',4335391),('Detroit-Warren-Livonia, MI',4296250),('Riverside-San Bernardino-Ontario, CA',4224851),('Phoenix-Mesa-Glendale, AZ',4192887),('Seattle-Tacoma-Bellevue, WA',3439809),('Minneapolis-St. Paul-Bloomington, MN-WI',3279833),('San Diego-Carlsbad-San Marcos, CA',3095313)]
df_pop=pd.DataFrame(topm, columns=["Metros","Population"])
df_pop
# Out:
#                                           Metros  Population
# 0          New York-Newark-Jersey City, NY-NJ-PA    18897109
# 1             Los Angeles-Long Beach-Anaheim, CA    12828837
# 2            Chicago-Joliet-Naperville, IL-IN-WI     9461105
# 3                Dallas-Fort Worth-Arlington, TX     6371773
# 4    Philadelphia-Camden-Wilmington, PA-NJ-DE-MD     5965343
# 5           Houston-The Woodlands-Sugar Land, TX     5946800
# 6   Washington-Arlington-Alexandria, DC-VA-MD-WV     5582170
# 7      Miami-Fort Lauderdale-West Palm Beach, FL     5564635
# 8             Atlanta-Sandy Springs-Marietta, GA     5268860
# 9                 Boston-Cambridge-Newton, MA-NH     4552402
# 10             San Francisco-Oakland-Hayward, CA     4335391
# 11                    Detroit-Warren-Livonia, MI     4296250
# 12          Riverside-San Bernardino-Ontario, CA     4224851
# 13                     Phoenix-Mesa-Glendale, AZ     4192887
# 14                   Seattle-Tacoma-Bellevue, WA     3439809
# 15       Minneapolis-St. Paul-Bloomington, MN-WI     3279833
# 16             San Diego-Carlsbad-San Marcos, CA     3095313

# %%
df_pop=df_pop.loc[df_pop['Metros'].isin(df_cut['Metropolitan area'])]
#df_cut.loc[df_cut['Metropolitan area'].isin(top20)]
df_pop
# Out:
#                                        Metros  Population
# 0       New York-Newark-Jersey City, NY-NJ-PA    18897109
# 1          Los Angeles-Long Beach-Anaheim, CA    12828837
# 5        Houston-The Woodlands-Sugar Land, TX     5946800
# 7   Miami-Fort Lauderdale-West Palm Beach, FL     5564635
# 9              Boston-Cambridge-Newton, MA-NH     4552402
# 10          San Francisco-Oakland-Hayward, CA     4335391

# %%
CLIENT_ID = '4UEC5WIWAML4RKIUBOMNQUMWM0TBVRO22JI1DGMDN1D1EIHI' # your Foursquare ID
CLIENT_SECRET = 'JWMIGGGHTO22FGYX3FXPVPJQUJPRL4RHT0CBJKASRY2XYIS3' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 400
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 4UEC5WIWAML4RKIUBOMNQUMWM0TBVRO22JI1DGMDN1D1EIHI
# CLIENT_SECRET:JWMIGGGHTO22FGYX3FXPVPJQUJPRL4RHT0CBJKASRY2XYIS3

# %%
address = 'Upper East Side, New York'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7737016 -73.9641196

# %%
search_query = 'Fashion'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# Fashion .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4UEC5WIWAML4RKIUBOMNQUMWM0TBVRO22JI1DGMDN1D1EIHI&client_secret=JWMIGGGHTO22FGYX3FXPVPJQUJPRL4RHT0CBJKASRY2XYIS3&ll=40.7737016,-73.9641196&v=20180604&query=Fashion&radius=2000&limit=400'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d7c7d95475abd002cd89bd6'},
#  'response': {'venues': [{'id': '4b632561f964a52052662ae3',
#     'name': 'Cohen Fashion Optical',
#     'location': {'address': '767 Lexington Ave',
#      'crossStreet': 'at E 60th St',
#      'lat': 40.76289465378699,
#      'lng': -73.96748587489128,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76289465378699,
#        'lng': -73.96748587489128}],
#      'distance': 1236,
#      'postalCode': '10065',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['767 Lexington Ave (at E 60th St)',
#       'New York, NY 10065',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d102951735',
#       'name': 'Accessories Store',
#       'pluralName': 'Accessories Stores',
#       'shortName': 'Accessories',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_accessories_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '5cd4464f79f6c7002c9f7367',
#     'name': 'Camp: Notes On Fashion',
#     'location': {'address': '1000 5th Ave',
#      'crossStreet': '82nd Street',
#      'lat': 40.778836,
#      'lng': -73.964591,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.778836,
#        'lng': -73.964591}],
#      'distance': 572,
#      'postalCode': '10028',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1000 5th Ave (82nd Street)',
#       'New York, NY 10028',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '52762533498e7efde0634f14',
#     'name': 'Passion Fashion Inc Store',
#     'location': {'address': '5 Avenue A',
#      'lat': 40.772953129937626,
#      'lng': -73.96663427352905,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.772953129937626,
#        'lng': -73.96663427352905}],
#      'distance': 227,
#      'postalCode': '10009',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['5 Avenue A',
#       'New York, NY 10009',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d108951735',
#       'name': "Women's Store",
#       'pluralName': "Women's Stores",
#       'shortName': "Women's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4c535166728920a1b88edf80',
#     'name': 'Cohens Fashion Optical',
#     'location': {'address': '177 E 86th St',
#      'crossStreet': 'at 3rd Ave',
#      'lat': 40.779116735224854,
#      'lng': -73.95411573731059,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.779116735224854,
#        'lng': -73.95411573731059}],
#      'distance': 1036,
#      'postalCode': '10028',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['177 E 86th St (at 3rd Ave)',
#       'New York, NY 10028',
#       'United States']},
#     'categories': [{'id': '4d954afda243a5684865b473',
#       'name': 'Optical Shop',
#       'pluralName': 'Optical Shops',
#       'shortName': 'Optical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4b686bc3f964a5207e772be3',
#     'name': "Cohen's Fashion Optical",
#     'location': {'address': '132 W 57th St',
#      'crossStreet': 'btwn 6th & 7th Aves.',
#      'lat': 40.764730137070416,
#      'lng': -73.97867470979696,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.764730137070416,
#        'lng': -73.97867470979696}],
#      'distance': 1582,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['132 W 57th St (btwn 6th & 7th Aves.)',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4d954afda243a5684865b473',
#       'name': 'Optical Shop',
#       'pluralName': 'Optical Shops',
#       'shortName': 'Optical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '515efecee4b0f2117b8feb6b',
#     'name': 'Fashion Views',
#     'location': {'address': '14 E 77th St',
#      'crossStreet': 'Madison Avenue',
#      'lat': 40.7741127596693,
#      'lng': -73.96415178592201,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7741127596693,
#        'lng': -73.96415178592201}],
#      'distance': 45,
#      'postalCode': '10075',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['14 E 77th St (Madison Avenue)',
#       'New York, NY 10075',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f4941735',
#       'name': 'Design Studio',
#       'pluralName': 'Design Studios',
#       'shortName': 'Design',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/design_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4b5cbf8bf964a520fd4129e3',
#     'name': 'Fashion 74 Nails',
#     'location': {'address': '303 Amsterdam Ave',
#      'crossStreet': 'W 74th St',
#      'lat': 40.7800711475545,
#      'lng': -73.9805242232855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7800711475545,
#        'lng': -73.9805242232855}],
#      'distance': 1554,
#      'postalCode': '10023',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['303 Amsterdam Ave (W 74th St)',
#       'New York, NY 10023',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10c951735',
#       'name': 'Cosmetics Shop',
#       'pluralName': 'Cosmetics Shops',
#       'shortName': 'Cosmetics',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4bc218c34cdfc9b6c5899521',
#     'name': 'Cohens Fashion Optical',
#     'location': {'address': '167 W 72nd St',
#      'crossStreet': 'Broadway and Amsterdam',
#      'lat': 40.7785091,
#      'lng': -73.9810001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7785091,
#        'lng': -73.9810001}],
#      'distance': 1520,
#      'postalCode': '10023',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['167 W 72nd St (Broadway and Amsterdam)',
#       'New York, NY 10023',
#       'United States']},
#     'categories': [{'id': '4d954afda243a5684865b473',
#       'name': 'Optical Shop',
#       'pluralName': 'Optical Shops',
#       'shortName': 'Optical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '5b92d1a2c0f163002c2b19a5',
#     'name': 'Fashion Nail & Spa',
#     'location': {'lat': 40.781724,
#      'lng': -73.958288,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.781724,
#        'lng': -73.958288}],
#      'distance': 1019,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10128', 'United States']},
#     'categories': [{'id': '4f04aa0c2fb6e1c99f3db0b8',
#       'name': 'Nail Salon',
#       'pluralName': 'Nail Salons',
#       'shortName': 'Nail Salon',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/nailsalon_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4cdd752a22bd721e59450148',
#     'name': 'New York Window Fashion',
#     'location': {'address': '244 W 72nd St',
#      'lat': 40.779401,
#      'lng': -73.98355,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.779401,
#        'lng': -73.98355}],
#      'distance': 1756,
#      'postalCode': '10023',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['244 W 72nd St',
#       'New York, NY 10023',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'shortName': 'Furniture / Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4b859e1af964a520ef6831e3',
#     'name': 'Fashion Nails',
#     'location': {'address': '353 E 77th St',
#      'crossStreet': '79th and 1st ave',
#      'lat': 40.7713312504939,
#      'lng': -73.95398009529737,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7713312504939,
#        'lng': -73.95398009529737}],
#      'distance': 894,
#      'postalCode': '10075',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['353 E 77th St (79th and 1st ave)',
#       'New York, NY 10075',
#       'United States']},
#     'categories': [{'id': '4f04aa0c2fb6e1c99f3db0b8',
#       'name': 'Nail Salon',
#       'pluralName': 'Nail Salons',
#       'shortName': 'Nail Salon',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/nailsalon_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4ba11914f964a520839737e3',
#     'name': "Cohen's Fashion Optical",
#     'location': {'address': '830 3rd Ave Frnt 4',
#      'crossStreet': 'btwn E. 49th & E. 50th Sts.',
#      'lat': 40.75629078933118,
#      'lng': -73.97074803929922,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75629078933118,
#        'lng': -73.97074803929922}],
#      'distance': 2017,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['830 3rd Ave Frnt 4 (btwn E. 49th & E. 50th Sts.)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d102951735',
#       'name': 'Accessories Store',
#       'pluralName': 'Accessories Stores',
#       'shortName': 'Accessories',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_accessories_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '5a7f0728535d6f1c35bf3842',
#     'name': 'society fashion week',
#     'location': {'address': '45 E 45th St',
#      'lat': 40.754676,
#      'lng': -73.97736,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.754676,
#        'lng': -73.97736}],
#      'distance': 2394,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['45 E 45th St',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '57704bb9498e8d87afc887ff',
#     'name': 'Fashion Spa',
#     'location': {'address': '899 1st Ave',
#      'lat': 40.75425739823174,
#      'lng': -73.96590843967779,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75425739823174,
#        'lng': -73.96590843967779}],
#      'distance': 2169,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['899 1st Ave',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4f04aa0c2fb6e1c99f3db0b8',
#       'name': 'Nail Salon',
#       'pluralName': 'Nail Salons',
#       'shortName': 'Nail Salon',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/nailsalon_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '357303442'},
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '534f16f9498e10207a145f7b',
#     'name': 'fashion diva nails',
#     'location': {'lat': 40.766381159404816,
#      'lng': -73.9624528248418,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.766381159404816,
#        'lng': -73.9624528248418}],
#      'distance': 826,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4f04aa0c2fb6e1c99f3db0b8',
#       'name': 'Nail Salon',
#       'pluralName': 'Nail Salons',
#       'shortName': 'Nail Salon',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/nailsalon_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '5c268a0312c8f0002c46e451',
#     'name': 'Fashionphile',
#     'location': {'lat': 40.773926,
#      'lng': -73.963792,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.773926,
#        'lng': -73.963792}],
#      'distance': 37,
#      'postalCode': '10021',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10021', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d102951735',
#       'name': 'Accessories Store',
#       'pluralName': 'Accessories Stores',
#       'shortName': 'Accessories',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_accessories_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '537bd39d498e043d3810be88',
#     'name': 'Taji Fashion',
#     'location': {'lat': 40.76472265701458,
#      'lng': -73.9701382084926,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76472265701458,
#        'lng': -73.9701382084926}],
#      'distance': 1120,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d106951735',
#       'name': "Men's Store",
#       'pluralName': "Men's Stores",
#       'shortName': "Men's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4b68663af964a5202a762be3',
#     'name': "Cohen's Fashion Optical",
#     'location': {'address': '1369 3rd Ave',
#      'crossStreet': 'Between 78th And 79',
#      'lat': 40.77367117154271,
#      'lng': -73.95747788250446,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77367117154271,
#        'lng': -73.95747788250446}],
#      'distance': 559,
#      'postalCode': '10075',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1369 3rd Ave (Between 78th And 79)',
#       'New York, NY 10075',
#       'United States']},
#     'categories': [{'id': '4d954afda243a5684865b473',
#       'name': 'Optical Shop',
#       'pluralName': 'Optical Shops',
#       'shortName': 'Optical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '541cb3df498e9ab3265a0491',
#     'name': 'Fashion Fairy Nail Spa',
#     'location': {'crossStreet': '48th St',
#      'lat': 40.754233226145935,
#      'lng': -73.97195740721317,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.754233226145935,
#        'lng': -73.97195740721317}],
#      'distance': 2265,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['48th St', 'New York, NY 10022', 'United States']},
#     'categories': [{'id': '4f04aa0c2fb6e1c99f3db0b8',
#       'name': 'Nail Salon',
#       'pluralName': 'Nail Salons',
#       'shortName': 'Nail Salon',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/nailsalon_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4e6c3ef0483b1f5ebe00ee28',
#     'name': 'Fashion 55',
#     'location': {'address': '47 W 56th St',
#      'crossStreet': 'between 5th and 6th Avenue',
#      'lat': 40.76429,
#      'lng': -73.973413,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76429,
#        'lng': -73.973413}],
#      'distance': 1308,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['47 W 56th St (between 5th and 6th Avenue)',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06376d81259',
#       'name': 'Nightlife Spot',
#       'pluralName': 'Nightlife Spots',
#       'shortName': 'Nightlife',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '55eb1f30498e1f69287100d1',
#     'name': 'Mix Fashion Jewelry',
#     'location': {'lat': 40.77674257743636,
#      'lng': -73.9555244530072,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77674257743636,
#        'lng': -73.9555244530072}],
#      'distance': 799,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111951735',
#       'name': 'Jewelry Store',
#       'pluralName': 'Jewelry Stores',
#       'shortName': 'Jewelry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4cf93cf46cee236acc98eb03',
#     'name': 'Fashion Etc.',
#     'location': {'address': '155 E 55th St',
#      'lat': 40.75932437436328,
#      'lng': -73.96903047605844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75932437436328,
#        'lng': -73.96903047605844}],
#      'distance': 1653,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['155 E 55th St',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '553104f7498e5f41b104fb82',
#     'name': 'Fashion Law Institute at Fordham Law School',
#     'location': {'address': '150 W 62nd St',
#      'lat': 40.771449,
#      'lng': -73.985108,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.771449,
#        'lng': -73.985108}],
#      'distance': 1787,
#      'postalCode': '10023',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['150 W 62nd St',
#       'New York, NY 10023',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4dbd9edc316a78b90c2a2543',
#     'name': 'Color Moves: Art and Fashion by Sonia Delaunay',
#     'location': {'address': '2 E 91st St',
#      'crossStreet': 'New York',
#      'lat': 40.784718,
#      'lng': -73.958096,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.784718,
#        'lng': -73.958096}],
#      'distance': 1327,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2 E 91st St (New York)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4d2cb48e55a8b60c8b3ff2c0',
#     'name': 'Fashion Week Daily',
#     'location': {'address': '135 W 50th St',
#      'crossStreet': 'at 7th Ave.',
#      'lat': 40.760985,
#      'lng': -73.982921,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.760985,
#        'lng': -73.982921}],
#      'distance': 2125,
#      'postalCode': '10020',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['135 W 50th St (at 7th Ave.)',
#       'New York, NY 10020',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '50756c4de4b0a0686386aff1',
#     'name': 'Fashion Digital New York',
#     'location': {'address': '1221 Avenue of the Americas',
#      'lat': 40.76002318799366,
#      'lng': -73.98236875781224,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76002318799366,
#        'lng': -73.98236875781224}],
#      'distance': 2164,
#      'postalCode': '10020',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1221 Avenue of the Americas',
#       'New York, NY 10020',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4c0aaf7a7e3fc928a211f482',
#     'name': "Kent's Fashion House",
#     'location': {'address': '1596 3rd Ave',
#      'lat': 40.781561274598374,
#      'lng': -73.95244816617493,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.781561274598374,
#        'lng': -73.95244816617493}],
#      'distance': 1316,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1596 3rd Ave',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '52681809498e8ca90bf56bdb',
#     'name': 'Cohen Fashion Optical',
#     'location': {'address': '3rd Avenue',
#      'crossStreet': '51rst Street',
#      'lat': 40.756437,
#      'lng': -73.970338,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.756437,
#        'lng': -73.970338}],
#      'distance': 1992,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['3rd Avenue (51rst Street)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4d954afda243a5684865b473',
#       'name': 'Optical Shop',
#       'pluralName': 'Optical Shops',
#       'shortName': 'Optical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '59457e1b17556232c3e41813',
#     'name': "Cohen's Fashion Optical of Harlem",
#     'location': {'address': '86 W 125th St',
#      'lat': 40.76190223247086,
#      'lng': -73.95697832107544,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76190223247086,
#        'lng': -73.95697832107544}],
#      'distance': 1444,
#      'postalCode': '10027',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['86 W 125th St',
#       'New York, NY 10027',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '51d19cb4498e11f873d1751c',
#     'name': 'LVMH Fashion Division',
#     'location': {'address': '495 Madison Avenue',
#      'lat': 40.762424,
#      'lng': -73.972566,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.762424,
#        'lng': -73.972566}],
#      'distance': 1443,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['495 Madison Avenue',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4f22cf7d6d867182dff6463b',
#     'name': 'Fit In Fashion Lounge Tailored by amNEWYORK',
#     'location': {'address': 'Empire Hotel 63rd',
#      'crossStreet': 'Broadway',
#      'lat': 40.771546950997056,
#      'lng': -73.98257732391357,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.771546950997056,
#        'lng': -73.98257732391357}],
#      'distance': 1574,
#      'postalCode': '10065',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Empire Hotel 63rd (Broadway)',
#       'New York, NY 10065',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '5203d5bd498e7df016dbc668',
#     'name': 'Fashion World',
#     'location': {'lat': 40.755778804191195,
#      'lng': -73.98248354107581,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.755778804191195,
#        'lng': -73.98248354107581}],
#      'distance': 2525,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111951735',
#       'name': 'Jewelry Store',
#       'pluralName': 'Jewelry Stores',
#       'shortName': 'Jewelry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '504aa8b1e4b09586578f27c5',
#     'name': 'Parkchoonmoo Fashion Show',
#     'location': {'address': 'Lincoln Center',
#      'lat': 40.772012,
#      'lng': -73.983224,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.772012,
#        'lng': -73.983224}],
#      'distance': 1621,
#      'postalCode': '10023',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Lincoln Center',
#       'New York, NY 10023',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ff931735',
#       'name': 'Convention Center',
#       'pluralName': 'Convention Centers',
#       'shortName': 'Convention Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/conventioncenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4f1f36a5e4b057da8b9c1cd4',
#     'name': 'Exclusive Fashion Club',
#     'location': {'address': '16 W 56th St',
#      'lat': 40.7629043528343,
#      'lng': -73.9757973016886,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7629043528343,
#        'lng': -73.9757973016886}],
#      'distance': 1553,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['16 W 56th St',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '5c02612f5f68b900330ecbe8',
#     'name': 'Nadin Fashion Alteration',
#     'location': {'address': '130 W 57th St #2e',
#      'lat': 40.76475,
#      'lng': -73.97861,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76475,
#        'lng': -73.97861}],
#      'distance': 1576,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['130 W 57th St #2e',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '5453de49498eade8af355881',
#       'name': 'Business Service',
#       'pluralName': 'Business Services',
#       'shortName': 'Business Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '524976543'},
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4e64e730091afcffd9f54084',
#     'name': 'Vanity Fair\'s "Fashion in Film"',
#     'location': {'address': '2 Columbus Cir',
#      'crossStreet': 'near 58th Street',
#      'lat': 40.76756198416912,
#      'lng': -73.98197650909424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76756198416912,
#        'lng': -73.98197650909424}],
#      'distance': 1653,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2 Columbus Cir (near 58th Street)',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d17e941735',
#       'name': 'Indie Movie Theater',
#       'pluralName': 'Indie Movie Theaters',
#       'shortName': 'Indie Movies',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '51956033498e5b0b8980ed10',
#     'name': "Cohen's Fashion Optical",
#     'location': {'address': '660 Lexington Ave',
#      'crossStreet': 'btwn E 56th St. & E 57th St.',
#      'lat': 40.759899060581084,
#      'lng': -73.97018283605576,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.759899060581084,
#        'lng': -73.97018283605576}],
#      'distance': 1619,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['660 Lexington Ave (btwn E 56th St. & E 57th St.)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4d954afda243a5684865b473',
#       'name': 'Optical Shop',
#       'pluralName': 'Optical Shops',
#       'shortName': 'Optical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '514fc9edfe70b220d5ed79c9',
#     'name': 'New York Window Fashion Inc',
#     'location': {'address': '244 W 72nd St',
#      'lat': 40.779371557459726,
#      'lng': -73.98371458053589,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.779371557459726,
#        'lng': -73.98371458053589}],
#      'distance': 1768,
#      'postalCode': '10023',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['244 W 72nd St',
#       'New York, NY 10023',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'shortName': 'Furniture / Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '53d0074c498e69e1d8954875',
#     'name': 'New York Fashion Tech Lab Demo Day',
#     'location': {'address': '300 W 57th St',
#      'lat': 40.767094376113164,
#      'lng': -73.98380354367815,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.767094376113164,
#        'lng': -73.98380354367815}],
#      'distance': 1815,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['300 W 57th St',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4df8ef88c65b6739205e0bd6',
#     'name': 'Institute Of Fashion And Technology',
#     'location': {'address': '303 W 56th St',
#      'lat': 40.76646973,
#      'lng': -73.98348281,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76646973,
#        'lng': -73.98348281}],
#      'distance': 1820,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['303 W 56th St',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1a8941735',
#       'name': 'General College & University',
#       'pluralName': 'General Colleges & Universities',
#       'shortName': 'Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4d7b9d6286cfa14300edb7a0',
#     'name': "Cohen's Fashion Optical",
#     'location': {'address': '500 Lexington Ave',
#      'crossStreet': '47th Street',
#      'lat': 40.75487054875991,
#      'lng': -73.97384136915207,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75487054875991,
#        'lng': -73.97384136915207}],
#      'distance': 2250,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['500 Lexington Ave (47th Street)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4d954afda243a5684865b473',
#       'name': 'Optical Shop',
#       'pluralName': 'Optical Shops',
#       'shortName': 'Optical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '5a0363e5a9fe1221191e8cdf',
#     'name': 'Items: Is Fashion Modern?',
#     'location': {'address': '11 W 53rd St',
#      'lat': 40.761809,
#      'lng': -73.977834,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.761809,
#        'lng': -73.977834}],
#      'distance': 1757,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['11 W 53rd St',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '56aa371be4b08b9a8d573532',
#       'name': 'Exhibit',
#       'pluralName': 'Exhibits',
#       'shortName': 'Exhibit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4b54c8c5f964a5204dcc27e3',
#     'name': 'Pet Fashion',
#     'location': {'address': '565 Columbus Ave.',
#      'crossStreet': 'Bet 87th and 88th',
#      'lat': 40.791299,
#      'lng': -73.965216,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.791299,
#        'lng': -73.965216}],
#      'distance': 1961,
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['565 Columbus Ave. (Bet 87th and 88th)',
#       'New York',
#       'United States']},
#     'categories': [{'id': '5032897c91d4c4b30a586d69',
#       'name': 'Pet Service',
#       'pluralName': 'Pet Services',
#       'shortName': 'Pet Service',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '53b45d90498e29c5f6bbcebd',
#     'name': 'Fourth Floor Fashion Talent',
#     'location': {'address': '1212 Avenue of the Americas',
#      'crossStreet': '48',
#      'lat': 40.7583425111342,
#      'lng': -73.94816029668492,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7583425111342,
#        'lng': -73.94816029668492}],
#      'distance': 2175,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1212 Avenue of the Americas (48)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4cb8a979c7228cfa9c530ace',
#     'name': 'American Fashion Designers at The Aldyn',
#     'location': {'address': '60 Riverside Blvd',
#      'crossStreet': 'West 63 Street',
#      'lat': 40.770914,
#      'lng': -73.988716,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.770914,
#        'lng': -73.988716}],
#      'distance': 2096,
#      'postalCode': '10069',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['60 Riverside Blvd (West 63 Street)',
#       'New York, NY 10069',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '534d1d70498e6ccf6dc2e8df',
#     'name': 'Manhattan Window Fashion',
#     'location': {'address': '252 E 50th St',
#      'lat': 40.75482991277171,
#      'lng': -73.96973490715027,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75482991277171,
#        'lng': -73.96973490715027}],
#      'distance': 2153,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['252 E 50th St',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '412878448'},
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4b5b7d49f964a5200b0229e3',
#     'name': "Cohen's Fashion Optical",
#     'location': {'address': '545 5th Ave',
#      'crossStreet': '45th Street',
#      'lat': 40.755279853640886,
#      'lng': -73.9796426351536,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.755279853640886,
#        'lng': -73.9796426351536}],
#      'distance': 2432,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['545 5th Ave (45th Street)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4d954afda243a5684865b473',
#       'name': 'Optical Shop',
#       'pluralName': 'Optical Shops',
#       'shortName': 'Optical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4e693a5ae4cdd38ef9b1bebb',
#     'name': 'Fashions Night Out-Calvin Klein Collection',
#     'location': {'address': '654 Madison Ave',
#      'lat': 40.76411519112605,
#      'lng': -73.9698053154773,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76411519112605,
#        'lng': -73.9698053154773}],
#      'distance': 1169,
#      'postalCode': '10065',
#      'cc': 'US',
#      'city': 'Manhattan',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['654 Madison Ave',
#       'Manhattan, NY 10065',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4c18fac1834e2d7f4ca62980',
#     'name': 'Fairchild Fashion Group',
#     'location': {'address': '750 3rd Ave',
#      'lat': 40.75440232801706,
#      'lng': -73.9730340403566,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75440232801706,
#        'lng': -73.9730340403566}],
#      'distance': 2276,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['750 3rd Ave',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1568439702',
#     'hasPerk': False},
#    {'id': '4dc14b241f6e7441cf49f022',
#     'name': 'Fashion140',
#     'location': {'lat': 40.773250608800616,
#      'lng': -73.98283362960618,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.773250608800616,
#        'lng': -73.98283362960618}],
#      'distance': 1578,
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['New York', 'United States']},
#     'categories': [],
#     'referralId': 'v-1568439702',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d102951735', 'name': 'A...    False
# 1  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d108951735', 'name': 'W...    False
# 3  [{'id': '4d954afda243a5684865b473', 'name': 'O...    False
# 4  [{'id': '4d954afda243a5684865b473', 'name': 'O...    False
#
#                          id   location.address location.cc location.city  \
# 0  4b632561f964a52052662ae3  767 Lexington Ave          US      New York
# 1  5cd4464f79f6c7002c9f7367       1000 5th Ave          US      New York
# 2  52762533498e7efde0634f14         5 Avenue A          US      New York
# 3  4c535166728920a1b88edf80      177 E 86th St          US      New York
# 4  4b686bc3f964a5207e772be3      132 W 57th St          US      New York
#
#   location.country  location.crossStreet  location.distance  \
# 0    United States          at E 60th St               1236
# 1    United States           82nd Street                572
# 2    United States                   NaN                227
# 3    United States            at 3rd Ave               1036
# 4    United States  btwn 6th & 7th Aves.               1582
#
#                            location.formattedAddress  \
# 0  [767 Lexington Ave (at E 60th St), New York, N...
# 1  [1000 5th Ave (82nd Street), New York, NY 1002...
# 2    [5 Avenue A, New York, NY 10009, United States]
# 3  [177 E 86th St (at 3rd Ave), New York, NY 1002...
# 4  [132 W 57th St (btwn 6th & 7th Aves.), New Yor...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 40.76289465378699...     40.762895
# 1  [{'label': 'display', 'lat': 40.778836, 'lng':...     40.778836
# 2  [{'label': 'display', 'lat': 40.77295312993762...     40.772953
# 3  [{'label': 'display', 'lat': 40.77911673522485...     40.779117
# 4  [{'label': 'display', 'lat': 40.76473013707041...     40.764730
#
#    location.lng location.postalCode location.state                       name  \
# 0    -73.967486               10065             NY      Cohen Fashion Optical
# 1    -73.964591               10028             NY     Camp: Notes On Fashion
# 2    -73.966634               10009             NY  Passion Fashion Inc Store
# 3    -73.954116               10028             NY     Cohens Fashion Optical
# 4    -73.978675               10019             NY    Cohen's Fashion Optical
#
#      referralId venuePage.id
# 0  v-1568439702          NaN
# 1  v-1568439702          NaN
# 2  v-1568439702          NaN
# 3  v-1568439702          NaN
# 4  v-1568439702          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                               name  \
# 0                            Cohen Fashion Optical
# 1                           Camp: Notes On Fashion
# 2                        Passion Fashion Inc Store
# 3                           Cohens Fashion Optical
# 4                          Cohen's Fashion Optical
# 5                                    Fashion Views
# 6                                 Fashion 74 Nails
# 7                           Cohens Fashion Optical
# 8                               Fashion Nail & Spa
# 9                          New York Window Fashion
# 10                                   Fashion Nails
# 11                         Cohen's Fashion Optical
# 12                            society fashion week
# 13                                     Fashion Spa
# 14                              fashion diva nails
# 15                                    Fashionphile
# 16                                    Taji Fashion
# 17                         Cohen's Fashion Optical
# 18                          Fashion Fairy Nail Spa
# 19                                      Fashion 55
# 20                             Mix Fashion Jewelry
# 21                                    Fashion Etc.
# 22     Fashion Law Institute at Fordham Law School
# 23  Color Moves: Art and Fashion by Sonia Delaunay
# 24                              Fashion Week Daily
# 25                        Fashion Digital New York
# 26                            Kent's Fashion House
# 27                           Cohen Fashion Optical
# 28               Cohen's Fashion Optical of Harlem
# 29                           LVMH Fashion Division
# 30     Fit In Fashion Lounge Tailored by amNEWYORK
# 31                                   Fashion World
# 32                       Parkchoonmoo Fashion Show
# 33                          Exclusive Fashion Club
# 34                        Nadin Fashion Alteration
# 35                 Vanity Fair's "Fashion in Film"
# 36                         Cohen's Fashion Optical
# 37                     New York Window Fashion Inc
# 38              New York Fashion Tech Lab Demo Day
# 39             Institute Of Fashion And Technology
# 40                         Cohen's Fashion Optical
# 41                       Items: Is Fashion Modern?
# 42                                     Pet Fashion
# 43                     Fourth Floor Fashion Talent
# 44         American Fashion Designers at The Aldyn
# 45                        Manhattan Window Fashion
# 46                         Cohen's Fashion Optical
# 47      Fashions Night Out-Calvin Klein Collection
# 48                         Fairchild Fashion Group
# 49                                      Fashion140
#
#                       categories                      address  cc       city  \
# 0              Accessories Store            767 Lexington Ave  US   New York
# 1                    Art Gallery                 1000 5th Ave  US   New York
# 2                  Women's Store                   5 Avenue A  US   New York
# 3                   Optical Shop                177 E 86th St  US   New York
# 4                   Optical Shop                132 W 57th St  US   New York
# 5                  Design Studio                 14 E 77th St  US   New York
# 6                 Cosmetics Shop            303 Amsterdam Ave  US   New York
# 7                   Optical Shop                167 W 72nd St  US   New York
# 8                     Nail Salon                          NaN  US   New York
# 9         Furniture / Home Store                244 W 72nd St  US   New York
# 10                    Nail Salon                353 E 77th St  US   New York
# 11             Accessories Store           830 3rd Ave Frnt 4  US   New York
# 12         General Entertainment                 45 E 45th St  US   New York
# 13                    Nail Salon                  899 1st Ave  US   New York
# 14                    Nail Salon                          NaN  US   New York
# 15             Accessories Store                          NaN  US   New York
# 16                   Men's Store                          NaN  US   New York
# 17                  Optical Shop                 1369 3rd Ave  US   New York
# 18                    Nail Salon                          NaN  US   New York
# 19                Nightlife Spot                 47 W 56th St  US   New York
# 20                 Jewelry Store                          NaN  US   New York
# 21                          None                155 E 55th St  US   New York
# 22     College Academic Building                150 W 62nd St  US   New York
# 23         General Entertainment                  2 E 91st St  US   New York
# 24                        Office                135 W 50th St  US   New York
# 25                   Event Space  1221 Avenue of the Americas  US   New York
# 26            Miscellaneous Shop                 1596 3rd Ave  US   New York
# 27                  Optical Shop                   3rd Avenue  US   New York
# 28               Doctor's Office                86 W 125th St  US   New York
# 29               Coworking Space           495 Madison Avenue  US   New York
# 30                      Boutique            Empire Hotel 63rd  US   New York
# 31                 Jewelry Store                          NaN  US   New York
# 32             Convention Center               Lincoln Center  US   New York
# 33                Clothing Store                 16 W 56th St  US   New York
# 34              Business Service            130 W 57th St #2e  US   New York
# 35           Indie Movie Theater               2 Columbus Cir  US   New York
# 36                  Optical Shop            660 Lexington Ave  US   New York
# 37        Furniture / Home Store                244 W 72nd St  US   New York
# 38                   Event Space                300 W 57th St  US   New York
# 39  General College & University                303 W 56th St  US   New York
# 40                  Optical Shop            500 Lexington Ave  US   New York
# 41                       Exhibit                 11 W 53rd St  US   New York
# 42                   Pet Service            565 Columbus Ave.  US        NaN
# 43                        Office  1212 Avenue of the Americas  US   New York
# 44                          None            60 Riverside Blvd  US   New York
# 45            Miscellaneous Shop                252 E 50th St  US   New York
# 46                  Optical Shop                  545 5th Ave  US   New York
# 47         General Entertainment              654 Madison Ave  US  Manhattan
# 48                        Office                  750 3rd Ave  US   New York
# 49                          None                          NaN  US        NaN
#
#           country                   crossStreet  distance  \
# 0   United States                  at E 60th St      1236
# 1   United States                   82nd Street       572
# 2   United States                           NaN       227
# 3   United States                    at 3rd Ave      1036
# 4   United States          btwn 6th & 7th Aves.      1582
# 5   United States                Madison Avenue        45
# 6   United States                     W 74th St      1554
# 7   United States        Broadway and Amsterdam      1520
# 8   United States                           NaN      1019
# 9   United States                           NaN      1756
# 10  United States              79th and 1st ave       894
# 11  United States   btwn E. 49th & E. 50th Sts.      2017
# 12  United States                           NaN      2394
# 13  United States                           NaN      2169
# 14  United States                           NaN       826
# 15  United States                           NaN        37
# 16  United States                           NaN      1120
# 17  United States           Between 78th And 79       559
# 18  United States                       48th St      2265
# 19  United States    between 5th and 6th Avenue      1308
# 20  United States                           NaN       799
# 21  United States                           NaN      1653
# 22  United States                           NaN      1787
# 23  United States                      New York      1327
# 24  United States                   at 7th Ave.      2125
# 25  United States                           NaN      2164
# 26  United States                           NaN      1316
# 27  United States                  51rst Street      1992
# 28  United States                           NaN      1444
# 29  United States                           NaN      1443
# 30  United States                      Broadway      1574
# 31  United States                           NaN      2525
# 32  United States                           NaN      1621
# 33  United States                           NaN      1553
# 34  United States                           NaN      1576
# 35  United States              near 58th Street      1653
# 36  United States  btwn E 56th St. & E 57th St.      1619
# 37  United States                           NaN      1768
# 38  United States                           NaN      1815
# 39  United States                           NaN      1820
# 40  United States                   47th Street      2250
# 41  United States                           NaN      1757
# 42  United States             Bet 87th and 88th      1961
# 43  United States                            48      2175
# 44  United States                West 63 Street      2096
# 45  United States                           NaN      2153
# 46  United States                   45th Street      2432
# 47  United States                           NaN      1169
# 48  United States                           NaN      2276
# 49  United States                           NaN      1578
#
#                                      formattedAddress  \
# 0   [767 Lexington Ave (at E 60th St), New York, N...
# 1   [1000 5th Ave (82nd Street), New York, NY 1002...
# 2     [5 Avenue A, New York, NY 10009, United States]
# 3   [177 E 86th St (at 3rd Ave), New York, NY 1002...
# 4   [132 W 57th St (btwn 6th & 7th Aves.), New Yor...
# 5   [14 E 77th St (Madison Avenue), New York, NY 1...
# 6   [303 Amsterdam Ave (W 74th St), New York, NY 1...
# 7   [167 W 72nd St (Broadway and Amsterdam), New Y...
# 8                 [New York, NY 10128, United States]
# 9   [244 W 72nd St, New York, NY 10023, United Sta...
# 10  [353 E 77th St (79th and 1st ave), New York, N...
# 11  [830 3rd Ave Frnt 4 (btwn E. 49th & E. 50th St...
# 12  [45 E 45th St, New York, NY 10017, United States]
# 13   [899 1st Ave, New York, NY 10022, United States]
# 14                      [New York, NY, United States]
# 15                [New York, NY 10021, United States]
# 16                      [New York, NY, United States]
# 17  [1369 3rd Ave (Between 78th And 79), New York,...
# 18       [48th St, New York, NY 10022, United States]
# 19  [47 W 56th St (between 5th and 6th Avenue), Ne...
# 20                      [New York, NY, United States]
# 21  [155 E 55th St, New York, NY 10022, United Sta...
# 22  [150 W 62nd St, New York, NY 10023, United Sta...
# 23  [2 E 91st St (New York), New York, NY 10128, U...
# 24  [135 W 50th St (at 7th Ave.), New York, NY 100...
# 25  [1221 Avenue of the Americas, New York, NY 100...
# 26  [1596 3rd Ave, New York, NY 10128, United States]
# 27  [3rd Avenue (51rst Street), New York, NY 10017...
# 28  [86 W 125th St, New York, NY 10027, United Sta...
# 29  [495 Madison Avenue, New York, NY 10022, Unite...
# 30  [Empire Hotel 63rd (Broadway), New York, NY 10...
# 31                      [New York, NY, United States]
# 32  [Lincoln Center, New York, NY 10023, United St...
# 33  [16 W 56th St, New York, NY 10019, United States]
# 34  [130 W 57th St #2e, New York, NY 10019, United...
# 35  [2 Columbus Cir (near 58th Street), New York, ...
# 36  [660 Lexington Ave (btwn E 56th St. & E 57th S...
# 37  [244 W 72nd St, New York, NY 10023, United Sta...
# 38  [300 W 57th St, New York, NY 10019, United Sta...
# 39  [303 W 56th St, New York, NY 10019, United Sta...
# 40  [500 Lexington Ave (47th Street), New York, NY...
# 41  [11 W 53rd St, New York, NY 10019, United States]
# 42  [565 Columbus Ave. (Bet 87th and 88th), New Yo...
# 43  [1212 Avenue of the Americas (48), New York, N...
# 44  [60 Riverside Blvd (West 63 Street), New York,...
# 45  [252 E 50th St, New York, NY 10022, United Sta...
# 46  [545 5th Ave (45th Street), New York, NY 10017...
# 47  [654 Madison Ave, Manhattan, NY 10065, United ...
# 48   [750 3rd Ave, New York, NY 10017, United States]
# 49                          [New York, United States]
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 40.76289465378699...  40.762895 -73.967486
# 1   [{'label': 'display', 'lat': 40.778836, 'lng':...  40.778836 -73.964591
# 2   [{'label': 'display', 'lat': 40.77295312993762...  40.772953 -73.966634
# 3   [{'label': 'display', 'lat': 40.77911673522485...  40.779117 -73.954116
# 4   [{'label': 'display', 'lat': 40.76473013707041...  40.764730 -73.978675
# 5   [{'label': 'display', 'lat': 40.7741127596693,...  40.774113 -73.964152
# 6   [{'label': 'display', 'lat': 40.7800711475545,...  40.780071 -73.980524
# 7   [{'label': 'display', 'lat': 40.7785091, 'lng'...  40.778509 -73.981000
# 8   [{'label': 'display', 'lat': 40.781724, 'lng':...  40.781724 -73.958288
# 9   [{'label': 'display', 'lat': 40.779401, 'lng':...  40.779401 -73.983550
# 10  [{'label': 'display', 'lat': 40.7713312504939,...  40.771331 -73.953980
# 11  [{'label': 'display', 'lat': 40.75629078933118...  40.756291 -73.970748
# 12  [{'label': 'display', 'lat': 40.754676, 'lng':...  40.754676 -73.977360
# 13  [{'label': 'display', 'lat': 40.75425739823174...  40.754257 -73.965908
# 14  [{'label': 'display', 'lat': 40.76638115940481...  40.766381 -73.962453
# 15  [{'label': 'display', 'lat': 40.773926, 'lng':...  40.773926 -73.963792
# 16  [{'label': 'display', 'lat': 40.76472265701458...  40.764723 -73.970138
# 17  [{'label': 'display', 'lat': 40.77367117154271...  40.773671 -73.957478
# 18  [{'label': 'display', 'lat': 40.75423322614593...  40.754233 -73.971957
# 19  [{'label': 'display', 'lat': 40.76429, 'lng': ...  40.764290 -73.973413
# 20  [{'label': 'display', 'lat': 40.77674257743636...  40.776743 -73.955524
# 21  [{'label': 'display', 'lat': 40.75932437436328...  40.759324 -73.969030
# 22  [{'label': 'display', 'lat': 40.771449, 'lng':...  40.771449 -73.985108
# 23  [{'label': 'display', 'lat': 40.784718, 'lng':...  40.784718 -73.958096
# 24  [{'label': 'display', 'lat': 40.760985, 'lng':...  40.760985 -73.982921
# 25  [{'label': 'display', 'lat': 40.76002318799366...  40.760023 -73.982369
# 26  [{'label': 'display', 'lat': 40.78156127459837...  40.781561 -73.952448
# 27  [{'label': 'display', 'lat': 40.756437, 'lng':...  40.756437 -73.970338
# 28  [{'label': 'display', 'lat': 40.76190223247086...  40.761902 -73.956978
# 29  [{'label': 'display', 'lat': 40.762424, 'lng':...  40.762424 -73.972566
# 30  [{'label': 'display', 'lat': 40.77154695099705...  40.771547 -73.982577
# 31  [{'label': 'display', 'lat': 40.75577880419119...  40.755779 -73.982484
# 32  [{'label': 'display', 'lat': 40.772012, 'lng':...  40.772012 -73.983224
# 33  [{'label': 'display', 'lat': 40.7629043528343,...  40.762904 -73.975797
# 34  [{'label': 'display', 'lat': 40.76475, 'lng': ...  40.764750 -73.978610
# 35  [{'label': 'display', 'lat': 40.76756198416912...  40.767562 -73.981977
# 36  [{'label': 'display', 'lat': 40.75989906058108...  40.759899 -73.970183
# 37  [{'label': 'display', 'lat': 40.77937155745972...  40.779372 -73.983715
# 38  [{'label': 'display', 'lat': 40.76709437611316...  40.767094 -73.983804
# 39  [{'label': 'display', 'lat': 40.76646973, 'lng...  40.766470 -73.983483
# 40  [{'label': 'display', 'lat': 40.75487054875991...  40.754871 -73.973841
# 41  [{'label': 'display', 'lat': 40.761809, 'lng':...  40.761809 -73.977834
# 42  [{'label': 'display', 'lat': 40.791299, 'lng':...  40.791299 -73.965216
# 43  [{'label': 'display', 'lat': 40.7583425111342,...  40.758343 -73.948160
# 44  [{'label': 'display', 'lat': 40.770914, 'lng':...  40.770914 -73.988716
# 45  [{'label': 'display', 'lat': 40.75482991277171...  40.754830 -73.969735
# 46  [{'label': 'display', 'lat': 40.75527985364088...  40.755280 -73.979643
# 47  [{'label': 'display', 'lat': 40.76411519112605...  40.764115 -73.969805
# 48  [{'label': 'display', 'lat': 40.75440232801706...  40.754402 -73.973034
# 49  [{'label': 'display', 'lat': 40.77325060880061...  40.773251 -73.982834
#
#    postalCode     state                        id
# 0       10065        NY  4b632561f964a52052662ae3
# 1       10028        NY  5cd4464f79f6c7002c9f7367
# 2       10009        NY  52762533498e7efde0634f14
# 3       10028        NY  4c535166728920a1b88edf80
# 4       10019        NY  4b686bc3f964a5207e772be3
# 5       10075        NY  515efecee4b0f2117b8feb6b
# 6       10023        NY  4b5cbf8bf964a520fd4129e3
# 7       10023        NY  4bc218c34cdfc9b6c5899521
# 8       10128        NY  5b92d1a2c0f163002c2b19a5
# 9       10023        NY  4cdd752a22bd721e59450148
# 10      10075        NY  4b859e1af964a520ef6831e3
# 11      10022        NY  4ba11914f964a520839737e3
# 12      10017        NY  5a7f0728535d6f1c35bf3842
# 13      10022        NY  57704bb9498e8d87afc887ff
# 14        NaN        NY  534f16f9498e10207a145f7b
# 15      10021        NY  5c268a0312c8f0002c46e451
# 16        NaN        NY  537bd39d498e043d3810be88
# 17      10075        NY  4b68663af964a5202a762be3
# 18      10022        NY  541cb3df498e9ab3265a0491
# 19      10019        NY  4e6c3ef0483b1f5ebe00ee28
# 20        NaN        NY  55eb1f30498e1f69287100d1
# 21      10022        NY  4cf93cf46cee236acc98eb03
# 22      10023        NY  553104f7498e5f41b104fb82
# 23      10128        NY  4dbd9edc316a78b90c2a2543
# 24      10020        NY  4d2cb48e55a8b60c8b3ff2c0
# 25      10020        NY  50756c4de4b0a0686386aff1
# 26      10128        NY  4c0aaf7a7e3fc928a211f482
# 27      10017        NY  52681809498e8ca90bf56bdb
# 28      10027        NY  59457e1b17556232c3e41813
# 29      10022        NY  51d19cb4498e11f873d1751c
# 30      10065        NY  4f22cf7d6d867182dff6463b
# 31        NaN        NY  5203d5bd498e7df016dbc668
# 32      10023        NY  504aa8b1e4b09586578f27c5
# 33      10019        NY  4f1f36a5e4b057da8b9c1cd4
# 34      10019        NY  5c02612f5f68b900330ecbe8
# 35      10019        NY  4e64e730091afcffd9f54084
# 36      10022        NY  51956033498e5b0b8980ed10
# 37      10023        NY  514fc9edfe70b220d5ed79c9
# 38      10019        NY  53d0074c498e69e1d8954875
# 39      10019        NY  4df8ef88c65b6739205e0bd6
# 40      10017        NY  4d7b9d6286cfa14300edb7a0
# 41      10019        NY  5a0363e5a9fe1221191e8cdf
# 42        NaN  New York  4b54c8c5f964a5204dcc27e3
# 43      10036        NY  53b45d90498e29c5f6bbcebd
# 44      10069        NY  4cb8a979c7228cfa9c530ace
# 45      10022        NY  534d1d70498e6ccf6dc2e8df
# 46      10017        NY  4b5b7d49f964a5200b0229e3
# 47      10065        NY  4e693a5ae4cdd38ef9b1bebb
# 48      10017        NY  4c18fac1834e2d7f4ca62980
# 49        NaN  New York  4dc14b241f6e7441cf49f022

# %%
dataframe_filtered['categories'].unique()
# Out:
# array(['Accessories Store', 'Art Gallery', "Women's Store",
#        'Optical Shop', 'Design Studio', 'Cosmetics Shop', 'Nail Salon',
#        'Furniture / Home Store', 'General Entertainment', "Men's Store",
#        'Nightlife Spot', 'Jewelry Store', None,
#        'College Academic Building', 'Office', 'Event Space',
#        'Miscellaneous Shop', "Doctor's Office", 'Coworking Space',
#        'Boutique', 'Convention Center', 'Clothing Store',
#        'Business Service', 'Indie Movie Theater',
#        'General College & University', 'Exhibit', 'Pet Service'],
#       dtype=object)

# %%
dataframe_filtered['crossStreet'].unique()
# Out:
# array(['at E 60th St', '82nd Street', nan, 'at 3rd Ave',
#        'btwn 6th & 7th Aves.', 'Madison Avenue', 'W 74th St',
#        'Broadway and Amsterdam', '79th and 1st ave',
#        'btwn E. 49th & E. 50th Sts.', 'Between 78th And 79', '48th St',
#        'between 5th and 6th Avenue', 'New York', 'at 7th Ave.',
#        '51rst Street', 'Broadway', 'near 58th Street',
#        'btwn E 56th St. & E 57th St.', '47th Street', 'Bet 87th and 88th',
#        '48', 'West 63 Street', '45th Street'], dtype=object)

# %% [markdown]
# Hence get a list of the fashion related businesses prevailing in the area and an idea of the popular locations for them as well.
